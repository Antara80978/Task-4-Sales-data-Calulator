# %% [markdown]
# <a href="https://colab.research.google.com/github/Antara80978/Task-4-Sales-data-Calulator/blob/main/task4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Sales Calculator**

# %% [markdown]
# step 1: import sales data

# %%
sales = [1200, 2500, 1800, 3200, 2100, 1500, 2800, 3500, 1700, 2300]

print("Sales Data:")
print(sales)
# Out:
# Sales Data:
# [1200, 2500, 1800, 3200, 2100, 1500, 2800, 3500, 1700, 2300]

# %% [markdown]
# step 2 : Calculate total sale

# %%
total_sales = sum(sales)

print("Total Sales:", total_sales)
# Out:
# Total Sales: 22600

# %% [markdown]
# step 3 :Calculate average

# %%
average_sales = total_sales / len(sales)

print("Average Sales:", average_sales)
# Out:
# Average Sales: 2260.0

# %% [markdown]
# Find the Lowest and highest sale

# %%
Highest_sale = max(sales)
Lowest_sale = min(sales)

print("Highest Sale:", Highest_sale)
print("Lowest Sale:", Lowest_sale)
# Out:
# Highest Sale: 3500
# Lowest Sale: 1200

# %% [markdown]
# Final Sales Analysis

# %%
print("========== SALES DATA ANALYSIS ==========")
print("Number of Sales :", len(sales))
print("Total Sales     :", total_sales)
print("Average Sales   :", average_sales)
print("Highest Sale    :", Highest_sale)
print("Lowest Sale     :", Lowest_sale)
print("==========================================")
# Out:
# ========== SALES DATA ANALYSIS ==========
# Number of Sales : 10
# Total Sales     : 22600
# Average Sales   : 2260.0
# Highest Sale    : 3500
# Lowest Sale     : 1200
# ...
